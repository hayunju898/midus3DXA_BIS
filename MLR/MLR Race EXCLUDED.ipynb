# %% [markdown]
# # Removing Race

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics 

#loading data
data = pd.read_csv('/Users/yunjuha/Desktop/MIDUS3/ML Models/Combined_MIDUS3_Refresher.csv')
df = pd.DataFrame(data)

#TRANSFORMING THE TARGETS
df['tjumppownums'] = np.log(df['jumppownums'] + 0.1)
df['tCOMB4IMaxGrip'] = np.sqrt(df['COMB4IMaxGrip'])

#dropping columns
column_to_drop = ['M2ID', 'MIDUSID', 'SAMPLMAJ', 'Height.cm.', 'Weight.kg.', 'Age.years.', 'TBW.litres.', 'ECF.litres.', 'ICF.litres.']
df = df.drop(column_to_drop, axis=1)

df = df.drop('COMB1PF7A', axis=1)

# %%
#total number of individuals when race is not included
df = df.dropna()
print(len(df))
# Out:
# 490

# %% [markdown]
# # MLR

# %%
#MLR Function

def train_test_linear_regression(df, feature_columns, target_column, test_size=0.2, random_state=42):
    columns = feature_columns + [target_column]
    X = df[columns]
    
    y = X.pop(target_column)
    
    #dividing into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    #TRAINING
    print("\nTRAINING Metrics")
    X_train_const = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_const)
    results = model.fit()
    print(results.summary())

    #TESTING
    print("\nTEST Metrics")
    mlr = LinearRegression()
    mlr.fit(X_train, y_train)

    #MLR coefficients
    print("\nCoefficients: ")
    coefficients = pd.Series(mlr.coef_, index=X.columns)
    print(coefficients)

    #MLR intercept
    print("\nIntercept: ")
    print(mlr.intercept_)

    test_pred = mlr.predict(X_test)

    mlr_diff = pd.DataFrame({'\nActual value': y_test, 'Predicted value': test_pred})
    mlr_diff.head()

    mse_test = metrics.mean_squared_error(y_test, test_pred)
    rmse_test = metrics.mean_squared_error(y_test, test_pred, squared=False)
    r2_test = metrics.r2_score(y_test, test_pred)

    print("MSE:", mse_test)
    print("RMSE:", rmse_test)
    print("R2:", r2_test)

# %%
#DXA: Handgrip Strength (ARMS)

print("MLR: DXA Model, Handgrip Strength (Arms)")

train_test_linear_regression(df, ['COMB4DALM', 'COMB4DABM', 'COMB4DAFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD'], 'tCOMB4IMaxGrip')
# Out:
# MLR: DXA Model, Handgrip Strength (Arms)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     62.46
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.35e-59
# Time:                        19:04:05   Log-Likelihood:                -427.26
# No. Observations:                 392   AIC:                             870.5
# Df Residuals:                     384   BIC:                             902.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.3873      1.289      1.852      0.065      -0.148       4.922
# COMB4DALM       0.0001   4.94e-05      2.921      0.004    4.72e-05       0.000
# COMB4DABM       0.0023      0.001      2.277      0.023       0.000       0.004
# COMB4DAFM      -0.0001   3.31e-05     -3.657      0.000      -0.000    -5.6e-05
# COMB1PRSEX     -0.2949      0.171     -1.728      0.085      -0.630       0.041
# COMB1PRAGE     -0.0085      0.004     -2.360      0.019      -0.016      -0.001
# COMB4P1A        0.0175      0.007      2.655      0.008       0.005       0.030
# COMB4DLR3MD    -0.2769      0.491     -0.564      0.573      -1.243       0.689
# ==============================================================================
# Omnibus:                       34.625   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.576
# Skew:                          -0.626   Prob(JB):                     1.72e-11
# Kurtosis:                       4.212   Cond. No.                     2.55e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB4DALM      0.000144
# COMB4DABM      0.002338
# COMB4DAFM     -0.000121
# COMB1PRSEX    -0.294852
# COMB1PRAGE    -0.008528
# COMB4P1A       0.017521
# COMB4DLR3MD   -0.276888
# dtype: float64
#
# Intercept:
# 2.38733446443245
# MSE: 0.5462081298831821
# RMSE: 0.739058948855355
# R2: 0.37421596030254756

# %%
print("MLR: DXA Model, Handgrip Strength (TB)")

train_test_linear_regression(df, ['COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD'], 'tCOMB4IMaxGrip')
# Out:
# MLR: DXA Model, Handgrip Strength (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     45.92
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.33e-55
# Time:                        19:06:21   Log-Likelihood:                -432.53
# No. Observations:                 392   AIC:                             885.1
# Df Residuals:                     382   BIC:                             924.8
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             2.7133      1.398      1.941      0.053      -0.035       5.462
# COMB4IALM         0.0391      0.015      2.621      0.009       0.010       0.068
# COMB4DTBBM        0.0004      0.000      1.468      0.143      -0.000       0.001
# COMB4DTBFM    -1.624e-05   3.94e-06     -4.124      0.000    -2.4e-05    -8.5e-06
# COMB1PRSEX       -0.4815      0.162     -2.978      0.003      -0.799      -0.164
# COMB1PRAGE       -0.0061      0.004     -1.615      0.107      -0.013       0.001
# COMB4P1A          0.0172      0.008      2.222      0.027       0.002       0.032
# COMB4DLR3MD       0.4796      0.495      0.969      0.333      -0.494       1.453
# COMB4DLFNMD      -0.3322      0.429     -0.775      0.439      -1.176       0.511
# COMB4DLSL14MD    -0.4160      0.314     -1.326      0.186      -1.033       0.201
# ==============================================================================
# Omnibus:                       25.687   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.908
# Skew:                          -0.511   Prob(JB):                     2.63e-08
# Kurtosis:                       4.046   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB4IALM        0.039054
# COMB4DTBBM       0.000367
# COMB4DTBFM      -0.000016
# COMB1PRSEX      -0.481485
# COMB1PRAGE      -0.006060
# COMB4P1A         0.017218
# COMB4DLR3MD      0.479559
# COMB4DLFNMD     -0.332211
# COMB4DLSL14MD   -0.416049
# dtype: float64
#
# Intercept:
# 2.7133469469373264
# MSE: 0.5075544877760917
# RMSE: 0.712428584333961
# R2: 0.41850096995988795

# %%
#DXA: Jump Power (LEGS)

print("MLR: DXA Model, Jump Power (Legs)")

train_test_linear_regression(df, ['COMB4ILLM', 'COMB4DLBM', 'COMB4DLFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLFNMD'], 'tjumppownums')
# Out:
# MLR: DXA Model, Jump Power (Legs)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     118.7
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           5.33e-92
# Time:                        19:04:08   Log-Likelihood:                 67.736
# No. Observations:                 392   AIC:                            -119.5
# Df Residuals:                     384   BIC:                            -87.70
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           1.0023      0.374      2.677      0.008       0.266       1.738
# COMB4ILLM       0.0415      0.005      7.675      0.000       0.031       0.052
# COMB4DLBM       0.0002      0.000      1.337      0.182   -8.47e-05       0.000
# COMB4DLFM   -1.546e-05    3.2e-06     -4.827      0.000   -2.18e-05   -9.16e-06
# COMB1PRSEX     -0.0991      0.046     -2.166      0.031      -0.189      -0.009
# COMB1PRAGE     -0.0138      0.001    -14.337      0.000      -0.016      -0.012
# COMB4P1A     8.671e-05      0.002      0.039      0.969      -0.004       0.004
# COMB4DLFNMD    -0.0135      0.107     -0.127      0.899      -0.224       0.197
# ==============================================================================
# Omnibus:                       97.812   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.045
# Skew:                          -1.141   Prob(JB):                     1.41e-64
# Kurtosis:                       6.577   Cond. No.                     4.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB4ILLM      0.041476
# COMB4DLBM      0.000180
# COMB4DLFM     -0.000015
# COMB1PRSEX    -0.099134
# COMB1PRAGE    -0.013793
# COMB4P1A       0.000087
# COMB4DLFNMD   -0.013522
# dtype: float64
#
# Intercept:
# 1.0022840155608415
# MSE: 0.026043462194396863
# RMSE: 0.16137986923528244
# R2: 0.7994776396926757

# %%
#DXA: Jump Power (TOTAL BODY)

print("MLR: DXA Model, Jump Power (TB)")

train_test_linear_regression(df, ['COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD'], 'tjumppownums')
# Out:
# MLR: DXA Model, Jump Power (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     101.4
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.40e-95
# Time:                        19:04:19   Log-Likelihood:                 81.212
# No. Observations:                 392   AIC:                            -142.4
# Df Residuals:                     382   BIC:                            -102.7
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.1187      0.377      2.968      0.003       0.378       1.860
# COMB4IALM         0.0291      0.004      7.248      0.000       0.021       0.037
# COMB4DTBBM        0.0002   6.74e-05      3.019      0.003     7.1e-05       0.000
# COMB4DTBFM    -4.873e-06   1.06e-06     -4.590      0.000   -6.96e-06   -2.79e-06
# COMB1PRSEX       -0.0613      0.044     -1.406      0.161      -0.147       0.024
# COMB1PRAGE       -0.0121      0.001    -11.933      0.000      -0.014      -0.010
# COMB4P1A         -0.0020      0.002     -0.949      0.343      -0.006       0.002
# COMB4DLR3MD       0.1292      0.133      0.968      0.334      -0.133       0.392
# COMB4DLFNMD       0.0200      0.116      0.173      0.863      -0.207       0.247
# COMB4DLSL14MD    -0.3238      0.085     -3.827      0.000      -0.490      -0.157
# ==============================================================================
# Omnibus:                       79.515   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.174
# Skew:                          -0.974   Prob(JB):                     6.25e-46
# Kurtosis:                       5.992   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB4IALM        0.029123
# COMB4DTBBM       0.000204
# COMB4DTBFM      -0.000005
# COMB1PRSEX      -0.061294
# COMB1PRAGE      -0.012073
# COMB4P1A        -0.001983
# COMB4DLR3MD      0.129227
# COMB4DLFNMD      0.019979
# COMB4DLSL14MD   -0.323778
# dtype: float64
#
# Intercept:
# 1.1187127320368713
# MSE: 0.026654068941565984
# RMSE: 0.1632607391308945
# R2: 0.7947762560882995

# %%
#BIS: Handgrip Strength

print("MLR: BIS Model, Handgrip Strength")

train_test_linear_regression(df, ['COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A'], 'tCOMB4IMaxGrip')
# Out:
# MLR: BIS Model, Handgrip Strength
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     38.00
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.07e-57
# Time:                        19:04:29   Log-Likelihood:                -421.43
# No. Observations:                 392   AIC:                             868.9
# Df Residuals:                     379   BIC:                             920.5
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.6662      2.455      0.271      0.786      -4.162       5.494
# COMB4IMECF      -3.0825      7.884     -0.391      0.696     -18.584      12.419
# COMB4IMICF      -3.1550      7.884     -0.400      0.689     -18.656      12.346
# COMB4IMFFM       2.2880      5.770      0.397      0.692      -9.057      13.633
# COMB4DTBFM   -1.195e-05   6.08e-06     -1.967      0.050   -2.39e-05   -2.96e-09
# COMB4IRES0      -0.0014      0.004     -0.372      0.710      -0.009       0.006
# COMB4IRESINF     0.0083      0.014      0.599      0.550      -0.019       0.036
# COMB4IRESEXC    -0.0014      0.004     -0.372      0.710      -0.009       0.006
# COMB4IRESINC    -0.0016      0.001     -1.635      0.103      -0.003       0.000
# COMB4IFCHAR      0.0011      0.015      0.073      0.942      -0.029       0.031
# COMB4IMCAP       0.1377      0.328      0.420      0.675      -0.507       0.783
# COMB1PRSEX      -0.4365      0.249     -1.756      0.080      -0.925       0.052
# COMB1PRAGE      -0.0031      0.004     -0.792      0.429      -0.011       0.005
# COMB4P1A         0.0370      0.012      2.995      0.003       0.013       0.061
# ==============================================================================
# Omnibus:                       31.848   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.307
# Skew:                          -0.597   Prob(JB):                     2.39e-10
# Kurtosis:                       4.135   Cond. No.                     3.59e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.14e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB4IMECF     -3.082519
# COMB4IMICF     -3.154977
# COMB4IMFFM      2.287961
# COMB4DTBFM     -0.000012
# COMB4IRES0     -0.001433
# COMB4IRESINF    0.008295
# COMB4IRESEXC   -0.001433
# COMB4IRESINC   -0.001575
# COMB4IFCHAR     0.001127
# COMB4IMCAP      0.137746
# COMB1PRSEX     -0.436510
# COMB1PRAGE     -0.003053
# COMB4P1A        0.037048
# dtype: float64
#
# Intercept:
# 0.6661803409847273
# MSE: 0.5389270367255711
# RMSE: 0.7341165007855164
# R2: 0.38255782055746135

# %%
#BIS: Jump Power

print("MLR: BIS Model, Jump Power")

train_test_linear_regression(df, ['COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A'], 'tjumppownums')
# Out:
# MLR: BIS Model, Jump Power
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     85.91
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):          3.53e-100
# Time:                        19:04:38   Log-Likelihood:                 99.434
# No. Observations:                 392   AIC:                            -172.9
# Df Residuals:                     379   BIC:                            -121.2
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.6782      0.650      2.581      0.010       0.400       2.957
# COMB4IMECF      -1.5312      2.088     -0.733      0.464      -5.636       2.574
# COMB4IMICF      -1.3602      2.088     -0.652      0.515      -5.465       2.745
# COMB4IMFFM       1.0596      1.528      0.693      0.488      -1.945       4.064
# COMB4DTBFM   -2.398e-06   1.61e-06     -1.490      0.137   -5.56e-06    7.66e-07
# COMB4IRES0      -0.0048      0.001     -4.755      0.000      -0.007      -0.003
# COMB4IRESINF     0.0173      0.004      4.726      0.000       0.010       0.025
# COMB4IRESEXC    -0.0048      0.001     -4.755      0.000      -0.007      -0.003
# COMB4IRESINC    -0.0011      0.000     -4.485      0.000      -0.002      -0.001
# COMB4IFCHAR     -0.0102      0.004     -2.510      0.013      -0.018      -0.002
# COMB4IMCAP      -0.1039      0.087     -1.196      0.232      -0.275       0.067
# COMB1PRSEX      -0.4259      0.066     -6.470      0.000      -0.555      -0.296
# COMB1PRAGE      -0.0110      0.001    -10.800      0.000      -0.013      -0.009
# COMB4P1A         0.0044      0.003      1.331      0.184      -0.002       0.011
# ==============================================================================
# Omnibus:                       51.032   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.294
# Skew:                          -0.728   Prob(JB):                     1.66e-22
# Kurtosis:                       5.006   Cond. No.                     3.59e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.14e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB4IMECF     -1.531236
# COMB4IMICF     -1.360192
# COMB4IMFFM      1.059646
# COMB4DTBFM     -0.000002
# COMB4IRES0     -0.004845
# COMB4IRESINF    0.017338
# COMB4IRESEXC   -0.004845
# COMB4IRESINC   -0.001144
# COMB4IFCHAR    -0.010237
# COMB4IMCAP     -0.103897
# COMB1PRSEX     -0.425928
# COMB1PRAGE     -0.011021
# COMB4P1A        0.004359
# dtype: float64
#
# Intercept:
# 1.6781784757384557
# MSE: 0.041087340622015064
# RMSE: 0.20270012486926361
# R2: 0.6836468800200445

# %%
#COMBO: Handgrip Strength (ARMS)

print("MLR: Combo Models, Handgrip Strength (Arms)")

train_test_linear_regression(df, ['COMB4DALM', 'COMB4DABM', 'COMB4DAFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tCOMB4IMaxGrip')
# Out:
# MLR: Combo Models, Handgrip Strength (Arms)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     29.77
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           5.78e-57
# Time:                        19:05:08   Log-Likelihood:                -415.57
# No. Observations:                 392   AIC:                             865.1
# Df Residuals:                     375   BIC:                             932.7
# Df Model:                          16
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.8072      2.528      0.319      0.750      -4.163       5.778
# COMB4DALM     3.218e-05   7.23e-05      0.445      0.656      -0.000       0.000
# COMB4DABM        0.0030      0.001      2.783      0.006       0.001       0.005
# COMB4DAFM    -5.851e-05   6.58e-05     -0.889      0.375      -0.000    7.09e-05
# COMB1PRSEX      -0.2053      0.271     -0.758      0.449      -0.738       0.327
# COMB1PRAGE      -0.0049      0.004     -1.187      0.236      -0.013       0.003
# COMB4P1A         0.0358      0.013      2.859      0.004       0.011       0.060
# COMB4DLR3MD     -0.6612      0.503     -1.315      0.189      -1.650       0.327
# COMB4IMECF      -6.4631      7.893     -0.819      0.413     -21.983       9.057
# COMB4IMICF      -6.5315      7.891     -0.828      0.408     -22.047       8.984
# COMB4IMFFM       4.7386      5.775      0.821      0.412      -6.617      16.094
# COMB4DTBFM    1.707e-07   9.78e-06      0.017      0.986   -1.91e-05    1.94e-05
# COMB4IRES0      -0.0029      0.004     -0.743      0.458      -0.010       0.005
# COMB4IRESINF     0.0127      0.014      0.916      0.360      -0.015       0.040
# COMB4IRESEXC    -0.0029      0.004     -0.743      0.458      -0.010       0.005
# COMB4IRESINC    -0.0019      0.001     -1.977      0.049      -0.004   -1.05e-05
# COMB4IFCHAR      0.0067      0.016      0.428      0.669      -0.024       0.037
# COMB4IMCAP       0.2644      0.328      0.807      0.420      -0.380       0.908
# ==============================================================================
# Omnibus:                       34.950   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.531
# Skew:                          -0.635   Prob(JB):                     1.76e-11
# Kurtosis:                       4.191   Cond. No.                     1.87e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.58e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB4DALM       3.218181e-05
# COMB4DABM       2.961331e-03
# COMB4DAFM      -5.850795e-05
# COMB1PRSEX     -2.053368e-01
# COMB1PRAGE     -4.858139e-03
# COMB4P1A        3.583868e-02
# COMB4DLR3MD    -6.611955e-01
# COMB4IMECF     -6.463086e+00
# COMB4IMICF     -6.531453e+00
# COMB4IMFFM      4.738609e+00
# COMB4DTBFM      1.706738e-07
# COMB4IRES0     -2.866833e-03
# COMB4IRESINF    1.266662e-02
# COMB4IRESEXC   -2.866833e-03
# COMB4IRESINC   -1.898704e-03
# COMB4IFCHAR     6.655472e-03
# COMB4IMCAP      2.643979e-01
# dtype: float64
#
# Intercept:
# 0.8071753509011641
# MSE: 0.5659812353622062
# RMSE: 0.7523172438288294
# R2: 0.35156215281221614

# %%
#COMBO: Handgrip Strength (TOTAL BODY)

print("MLR: Combo Models, Handgrip Strength (TB)")

train_test_linear_regression(df, ['COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD', 'COMB4IMECF', 'COMB4IMICF','COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tCOMB4IMaxGrip')
# Out:
# MLR: Combo Models, Handgrip Strength (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     26.90
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.47e-54
# Time:                        19:05:20   Log-Likelihood:                -419.71
# No. Observations:                 392   AIC:                             875.4
# Df Residuals:                     374   BIC:                             946.9
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.7088      2.656      0.643      0.520      -3.513       6.930
# COMB4IALM        -0.0161      0.024     -0.685      0.493      -0.062       0.030
# COMB4DTBBM        0.0004      0.000      1.470      0.142      -0.000       0.001
# COMB4DTBFM    -6.119e-06   3.14e-06     -1.950      0.052   -1.23e-05    5.06e-08
# COMB1PRSEX       -0.3660      0.272     -1.344      0.180      -0.901       0.169
# COMB1PRAGE       -0.0028      0.004     -0.668      0.504      -0.011       0.005
# COMB4P1A          0.0302      0.013      2.316      0.021       0.005       0.056
# COMB4DLR3MD       0.1607      0.500      0.321      0.748      -0.823       1.144
# COMB4DLFNMD      -0.2303      0.425     -0.542      0.588      -1.065       0.605
# COMB4DLSL14MD    -0.4492      0.315     -1.425      0.155      -1.069       0.171
# COMB4IMECF       -3.3924      7.995     -0.424      0.672     -19.114      12.329
# COMB4IMICF       -3.4509      7.995     -0.432      0.666     -19.172      12.270
# COMB4IMFFM        2.5123      5.851      0.429      0.668      -8.993      14.017
# COMB4DTBFM    -6.118e-06   3.14e-06     -1.950      0.052   -1.23e-05    5.11e-08
# COMB4IRES0       -0.0012      0.004     -0.318      0.751      -0.009       0.006
# COMB4IRESINF      0.0072      0.014      0.509      0.611      -0.020       0.035
# COMB4IRESEXC     -0.0012      0.004     -0.318      0.751      -0.009       0.006
# COMB4IRESINC     -0.0015      0.001     -1.489      0.137      -0.003       0.000
# COMB4IFCHAR       0.0006      0.016      0.039      0.969      -0.031       0.032
# COMB4IMCAP        0.0953      0.339      0.281      0.779      -0.571       0.762
# ==============================================================================
# Omnibus:                       29.932   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.719
# Skew:                          -0.567   Prob(JB):                     8.73e-10
# Kurtosis:                       4.127   Cond. No.                     1.42e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.29e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB4IALM       -0.016142
# COMB4DTBBM       0.000365
# COMB4DTBFM      -0.000006
# COMB1PRSEX      -0.365985
# COMB1PRAGE      -0.002795
# COMB4P1A         0.030219
# COMB4DLR3MD      0.160669
# COMB4DLFNMD     -0.230322
# COMB4DLSL14MD   -0.449217
# COMB4IMECF      -3.392400
# COMB4IMICF      -3.450853
# COMB4IMFFM       2.512327
# COMB4DTBFM      -0.000006
# COMB4IRES0      -0.001242
# COMB4IRESINF     0.007164
# COMB4IRESEXC    -0.001242
# COMB4IRESINC    -0.001465
# COMB4IFCHAR      0.000630
# COMB4IMCAP       0.095314
# dtype: float64
#
# Intercept:
# 1.7087586508646289
# MSE: 0.5444770283646966
# RMSE: 0.7378868669143641
# R2: 0.3761992623482274

# %%
#COMBO: Jump Power (LEGS)

print("MLR: Combo Models, Jump Power (Legs)")

train_test_linear_regression(df, ['COMB4ILLM', 'COMB4DLBM', 'COMB4DLFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLFNMD', 'COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tjumppownums')
# Out:
# MLR: Combo Models, Jump Power (Legs)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.737
# Method:                 Least Squares   F-statistic:                     69.36
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):          2.17e-101
# Time:                        19:05:39   Log-Likelihood:                 111.66
# No. Observations:                 392   AIC:                            -189.3
# Df Residuals:                     375   BIC:                            -121.8
# Df Model:                          16
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.0276      0.672      1.529      0.127      -0.294       2.349
# COMB4ILLM        0.0334      0.008      4.026      0.000       0.017       0.050
# COMB4DLBM        0.0001      0.000      1.037      0.300      -0.000       0.000
# COMB4DLFM    -1.013e-05    5.3e-06     -1.910      0.057   -2.06e-05    2.97e-07
# COMB1PRSEX      -0.3228      0.070     -4.624      0.000      -0.460      -0.186
# COMB1PRAGE      -0.0101      0.001     -9.507      0.000      -0.012      -0.008
# COMB4P1A         0.0043      0.003      1.249      0.213      -0.002       0.011
# COMB4DLFNMD      0.0504      0.099      0.508      0.612      -0.145       0.245
# COMB4IMECF      -1.7664      2.051     -0.861      0.390      -5.799       2.266
# COMB4IMICF      -1.6259      2.051     -0.793      0.428      -5.658       2.406
# COMB4IMFFM       1.2311      1.501      0.820      0.413      -1.720       4.182
# COMB4DTBFM    8.556e-07   2.31e-06      0.371      0.711   -3.68e-06    5.39e-06
# COMB4IRES0      -0.0052      0.001     -5.143      0.000      -0.007      -0.003
# COMB4IRESINF     0.0189      0.004      5.230      0.000       0.012       0.026
# COMB4IRESEXC    -0.0052      0.001     -5.143      0.000      -0.007      -0.003
# COMB4IRESINC    -0.0013      0.000     -5.232      0.000      -0.002      -0.001
# COMB4IFCHAR     -0.0046      0.004     -1.119      0.264      -0.013       0.004
# COMB4IMCAP      -0.0034      0.087     -0.039      0.969      -0.175       0.168
# ==============================================================================
# Omnibus:                       77.017   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.546
# Skew:                          -0.934   Prob(JB):                     8.55e-46
# Kurtosis:                       6.037   Cond. No.                     6.74e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.29e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB4ILLM       3.336337e-02
# COMB4DLBM       1.272122e-04
# COMB4DLFM      -1.012982e-05
# COMB1PRSEX     -3.228359e-01
# COMB1PRAGE     -1.007115e-02
# COMB4P1A        4.260004e-03
# COMB4DLFNMD     5.037197e-02
# COMB4IMECF     -1.766375e+00
# COMB4IMICF     -1.625935e+00
# COMB4IMFFM      1.231145e+00
# COMB4DTBFM      8.555696e-07
# COMB4IRES0     -5.153661e-03
# COMB4IRESINF    1.887151e-02
# COMB4IRESEXC   -5.153661e-03
# COMB4IRESINC   -1.317063e-03
# COMB4IFCHAR    -4.630995e-03
# COMB4IMCAP     -3.411930e-03
# dtype: float64
#
# Intercept:
# 1.0275687038935553
# MSE: 0.03767458224350986
# RMSE: 0.19409941330027214
# R2: 0.7099235079164572

# %%
#COMBO: Jump Power (TOTAL BODY)

print("MLR: Combo Models, Jump Power (TB)")

train_test_linear_regression(df, ['COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD', 'COMB4IMECF', 'COMB4IMICF','COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tjumppownums')
# Out:
# MLR: Combo Models, Jump Power (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     69.58
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):          1.79e-104
# Time:                        19:05:50   Log-Likelihood:                 121.47
# No. Observations:                 392   AIC:                            -206.9
# Df Residuals:                     374   BIC:                            -135.5
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.2410      0.668      1.859      0.064      -0.072       2.554
# COMB4IALM         0.0243      0.006      4.103      0.000       0.013       0.036
# COMB4DTBBM        0.0002   6.25e-05      3.276      0.001    8.18e-05       0.000
# COMB4DTBFM     -8.99e-07   7.89e-07     -1.140      0.255   -2.45e-06    6.52e-07
# COMB1PRSEX       -0.2730      0.068     -3.988      0.000      -0.408      -0.138
# COMB1PRAGE       -0.0094      0.001     -8.935      0.000      -0.011      -0.007
# COMB4P1A          0.0026      0.003      0.780      0.436      -0.004       0.009
# COMB4DLR3MD      -0.0633      0.126     -0.503      0.615      -0.311       0.184
# COMB4DLFNMD       0.0487      0.107      0.456      0.649      -0.161       0.259
# COMB4DLSL14MD    -0.2491      0.079     -3.142      0.002      -0.405      -0.093
# COMB4IMECF       -2.4231      2.010     -1.205      0.229      -6.376       1.530
# COMB4IMICF       -2.2969      2.010     -1.143      0.254      -6.250       1.656
# COMB4IMFFM        1.7158      1.471      1.166      0.244      -1.177       4.609
# COMB4DTBFM    -8.987e-07   7.89e-07     -1.139      0.255   -2.45e-06    6.52e-07
# COMB4IRES0       -0.0050      0.001     -5.066      0.000      -0.007      -0.003
# COMB4IRESINF      0.0182      0.004      5.155      0.000       0.011       0.025
# COMB4IRESEXC     -0.0050      0.001     -5.066      0.000      -0.007      -0.003
# COMB4IRESINC     -0.0013      0.000     -5.281      0.000      -0.002      -0.001
# COMB4IFCHAR      -0.0037      0.004     -0.923      0.356      -0.012       0.004
# COMB4IMCAP        0.0028      0.085      0.033      0.974      -0.165       0.170
# ==============================================================================
# Omnibus:                       67.912   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.030
# Skew:                          -0.863   Prob(JB):                     2.41e-36
# Kurtosis:                       5.657   Cond. No.                     1.42e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.29e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB4IALM        2.429682e-02
# COMB4DTBBM       2.047233e-04
# COMB4DTBFM      -8.988388e-07
# COMB1PRSEX      -2.730142e-01
# COMB1PRAGE      -9.392575e-03
# COMB4P1A         2.557382e-03
# COMB4DLR3MD     -6.330875e-02
# COMB4DLFNMD      4.865942e-02
# COMB4DLSL14MD   -2.490598e-01
# COMB4IMECF      -2.423068e+00
# COMB4IMICF      -2.296887e+00
# COMB4IMFFM       1.715757e+00
# COMB4DTBFM      -8.988569e-07
# COMB4IRES0      -4.977673e-03
# COMB4IRESINF     1.823166e-02
# COMB4IRESEXC    -4.977673e-03
# COMB4IRESINC    -1.306919e-03
# COMB4IFCHAR     -3.726820e-03
# COMB4IMCAP       2.817523e-03
# dtype: float64
#
# Intercept:
# 1.2410157635067491
# MSE: 0.03532909928938563
# RMSE: 0.18796036627274812
# R2: 0.7279826190481091
