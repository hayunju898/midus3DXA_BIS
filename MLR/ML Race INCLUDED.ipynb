# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler 

#loading data
data = pd.read_csv('/Users/yunjuha/Desktop/MIDUS3/ML Models/Combined_MIDUS3_Refresher.csv')
df = pd.DataFrame(data)

#TRANSFORMING THE TARGETS
df['tjumppownums'] = np.log(df['jumppownums'] + 0.1)
df['tCOMB4IMaxGrip'] = np.sqrt(df['COMB4IMaxGrip'])

#dropping columns
column_to_drop = ['M2ID', 'MIDUSID', 'SAMPLMAJ', 'Height.cm.', 'Weight.kg.', 'Age.years.', 'TBW.litres.', 'ECF.litres.', 'ICF.litres.']
df = df.drop(column_to_drop, axis=1)

# %%
#number of individuals before NA is removed
print(len(df))
# Out:
# 544

# %%
#this is the number of people we have when race IS INCLUDED
df = df.dropna()
print(len(df))
# Out:
# 422

# %%
#counting the total number of individuals who are white or black (ignore the other races for now...)
race = (df['COMB1PF7A'] == 1) | (df['COMB1PF7A'] == 2)
df = df[race]

print(len(df))
# Out:
# 413

# %% [markdown]
# # MLR

# %%
#MLR Function

def train_test_linear_regression(df, feature_columns, target_column, test_size=0.2, random_state=42):
    columns = feature_columns + [target_column]
    X = df[columns]
    
    y = X.pop(target_column)
    
    #dividing the data into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    #TRAINING
    print("\nTRAINING Metrics")
    X_train_const = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_const)
    results = model.fit()
    print(results.summary())

    #TESTING
    print("\nTEST Metrics")
    mlr = LinearRegression()
    mlr.fit(X_train, y_train)

    #MLR coefficients
    print("\nCoefficients: ")
    coefficients = pd.Series(mlr.coef_, index=X.columns)
    print(coefficients)

    #MLR intercept
    print("\nIntercept: ")
    print(mlr.intercept_)

    test_pred = mlr.predict(X_test)

    mlr_diff = pd.DataFrame({'\nActual value': y_test, 'Predicted value': test_pred})
    mlr_diff.head()

    mse_test = metrics.mean_squared_error(y_test, test_pred)
    rmse_test = metrics.mean_squared_error(y_test, test_pred, squared=False)
    r2_test = metrics.r2_score(y_test, test_pred)

    print("MSE:", mse_test)
    print("RMSE:", rmse_test)
    print("R2:", r2_test, "\n")
    
    #count the frequencies in training data
    white_train_counts = X_train[X_train['COMB1PF7A'] == 1]['COMB1PF7A'].value_counts()
    white_test_counts = X_test[X_test['COMB1PF7A'] == 1]['COMB1PF7A'].value_counts()

    black_train_counts = X_train[X_train['COMB1PF7A'] == 2]['COMB1PF7A'].value_counts()
    black_test_counts = X_test[X_test['COMB1PF7A'] == 2]['COMB1PF7A'].value_counts()
    
    print("white train frequency: ", white_train_counts.values[0])
    print("white test frequency: ", white_test_counts.values[0], "\n")
    
    print("black train frequency: ", black_train_counts.values[0])
    print("black test frequency: ", black_test_counts.values[0])

# %%
#DXA: Handgrip Strength (ARMS)

print("MLR: DXA Model, Handgrip Strength (Arms)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4DALM', 'COMB4DABM', 'COMB4DAFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD'], 'tCOMB4IMaxGrip')
# Out:
# MLR: DXA Model, Handgrip Strength (Arms)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     43.17
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.25e-46
# Time:                        18:54:30   Log-Likelihood:                -353.33
# No. Observations:                 330   AIC:                             724.7
# Df Residuals:                     321   BIC:                             758.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           3.6868      1.388      2.656      0.008       0.956       6.418
# COMB1PF7A      -0.3552      0.106     -3.357      0.001      -0.563      -0.147
# COMB4DALM       0.0001   5.12e-05      2.328      0.021    1.85e-05       0.000
# COMB4DABM       0.0014      0.001      1.321      0.187      -0.001       0.004
# COMB4DAFM   -8.345e-05    3.5e-05     -2.383      0.018      -0.000   -1.45e-05
# COMB1PRSEX     -0.5048      0.180     -2.799      0.005      -0.860      -0.150
# COMB1PRAGE     -0.0089      0.004     -2.320      0.021      -0.016      -0.001
# COMB4P1A        0.0162      0.007      2.289      0.023       0.002       0.030
# COMB4DLR3MD    -0.2410      0.516     -0.467      0.641      -1.256       0.774
# ==============================================================================
# Omnibus:                        4.828   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                4.868
# Skew:                          -0.296   Prob(JB):                       0.0877
# Kurtosis:                       2.932   Cond. No.                     2.53e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.53e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A     -0.355157
# COMB4DALM      0.000119
# COMB4DABM      0.001425
# COMB4DAFM     -0.000083
# COMB1PRSEX    -0.504819
# COMB1PRAGE    -0.008879
# COMB4P1A       0.016207
# COMB4DLR3MD   -0.240964
# dtype: float64
#
# Intercept:
# 3.6868217188775887
# MSE: 0.39219886272922283
# RMSE: 0.6262578244854293
# R2: 0.5894195899519463
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#DXA: Hangrip Strength (TOTAL BODY)

print("MLR: DXA Model, Handgrip Strength (TB)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD'], 'tCOMB4IMaxGrip')
# Out:
# MLR: DXA Model, Handgrip Strength (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     34.79
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.80e-45
# Time:                        18:56:14   Log-Likelihood:                -352.16
# No. Observations:                 330   AIC:                             726.3
# Df Residuals:                     319   BIC:                             768.1
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             2.4633      1.514      1.627      0.105      -0.516       5.442
# COMB1PF7A        -0.3452      0.106     -3.257      0.001      -0.554      -0.137
# COMB4IALM         0.0532      0.016      3.292      0.001       0.021       0.085
# COMB4DTBBM       -0.0003      0.000     -0.947      0.344      -0.001       0.000
# COMB4DTBFM    -1.625e-05   4.18e-06     -3.884      0.000   -2.45e-05   -8.02e-06
# COMB1PRSEX       -0.6289      0.167     -3.763      0.000      -0.958      -0.300
# COMB1PRAGE       -0.0060      0.004     -1.538      0.125      -0.014       0.002
# COMB4P1A          0.0239      0.008      2.846      0.005       0.007       0.040
# COMB4DLR3MD       0.7214      0.525      1.373      0.171      -0.312       1.755
# COMB4DLFNMD       0.0065      0.455      0.014      0.989      -0.888       0.901
# COMB4DLSL14MD     0.0847      0.350      0.242      0.809      -0.605       0.774
# ==============================================================================
# Omnibus:                        3.299   Durbin-Watson:                   1.833
# Prob(Omnibus):                  0.192   Jarque-Bera (JB):                3.348
# Skew:                          -0.241   Prob(JB):                        0.188
# Kurtosis:                       2.893   Cond. No.                     1.43e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A       -0.345232
# COMB4IALM        0.053220
# COMB4DTBBM      -0.000270
# COMB4DTBFM      -0.000016
# COMB1PRSEX      -0.628851
# COMB1PRAGE      -0.006049
# COMB4P1A         0.023869
# COMB4DLR3MD      0.721356
# COMB4DLFNMD      0.006540
# COMB4DLSL14MD    0.084735
# dtype: float64
#
# Intercept:
# 2.463286250452244
# MSE: 0.42786825358862773
# RMSE: 0.6541163914691541
# R2: 0.552078448717353
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#DXA: Jump Power (LEGS)

print("MLR: DXA Model, Jump Power (Legs)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4ILLM', 'COMB4DLBM', 'COMB4DLFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLFNMD'], 'tjumppownums')
# Out:
# MLR: DXA Model, Jump Power (Legs)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     115.3
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.18e-89
# Time:                        18:56:43   Log-Likelihood:                 93.457
# No. Observations:                 330   AIC:                            -168.9
# Df Residuals:                     321   BIC:                            -134.7
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.6163      0.378      1.630      0.104      -0.127       1.360
# COMB1PF7A      -0.0124      0.027     -0.461      0.645      -0.065       0.040
# COMB4ILLM       0.0512      0.005      9.882      0.000       0.041       0.061
# COMB4DLBM       0.0002      0.000      1.112      0.267      -0.000       0.000
# COMB4DLFM   -1.668e-05   3.14e-06     -5.311      0.000   -2.29e-05   -1.05e-05
# COMB1PRSEX     -0.0307      0.043     -0.705      0.481      -0.116       0.055
# COMB1PRAGE     -0.0126      0.001    -13.073      0.000      -0.015      -0.011
# COMB4P1A        0.0007      0.002      0.328      0.743      -0.004       0.005
# COMB4DLFNMD    -0.0125      0.109     -0.115      0.909      -0.227       0.202
# ==============================================================================
# Omnibus:                      133.205   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              694.638
# Skew:                          -1.617   Prob(JB):                    1.45e-151
# Kurtosis:                       9.329   Cond. No.                     4.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A     -0.012400
# COMB4ILLM      0.051193
# COMB4DLBM      0.000152
# COMB4DLFM     -0.000017
# COMB1PRSEX    -0.030650
# COMB1PRAGE    -0.012636
# COMB4P1A       0.000727
# COMB4DLFNMD   -0.012481
# dtype: float64
#
# Intercept:
# 0.6163188511902395
# MSE: 0.03160772803062033
# RMSE: 0.1777856238018708
# R2: 0.7681879778110985
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#DXA: Jump Power (TOTAL BODY)
print("MLR: DXA Model, Jump Power (TB)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD'], 'tjumppownums')
# Out:
# MLR: DXA Model, Jump Power (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     105.6
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           6.25e-95
# Time:                        18:56:59   Log-Likelihood:                 111.08
# No. Observations:                 330   AIC:                            -200.2
# Df Residuals:                     319   BIC:                            -158.4
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.7467      0.372      2.007      0.046       0.015       1.478
# COMB1PF7A        -0.0538      0.026     -2.065      0.040      -0.105      -0.003
# COMB4IALM         0.0347      0.004      8.737      0.000       0.027       0.043
# COMB4DTBBM        0.0002      7e-05      2.744      0.006    5.43e-05       0.000
# COMB4DTBFM    -4.613e-06   1.03e-06     -4.487      0.000   -6.64e-06   -2.59e-06
# COMB1PRSEX        0.0234      0.041      0.571      0.569      -0.057       0.104
# COMB1PRAGE       -0.0110      0.001    -11.338      0.000      -0.013      -0.009
# COMB4P1A         -0.0019      0.002     -0.928      0.354      -0.006       0.002
# COMB4DLR3MD       0.3249      0.129      2.518      0.012       0.071       0.579
# COMB4DLFNMD       0.0517      0.112      0.463      0.644      -0.168       0.271
# COMB4DLSL14MD    -0.3836      0.086     -4.455      0.000      -0.553      -0.214
# ==============================================================================
# Omnibus:                       97.282   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              363.551
# Skew:                          -1.240   Prob(JB):                     1.14e-79
# Kurtosis:                       7.504   Cond. No.                     1.43e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A       -0.053778
# COMB4IALM        0.034700
# COMB4DTBBM       0.000192
# COMB4DTBFM      -0.000005
# COMB1PRSEX       0.023433
# COMB1PRAGE      -0.010955
# COMB4P1A        -0.001912
# COMB4DLR3MD      0.324878
# COMB4DLFNMD      0.051663
# COMB4DLSL14MD   -0.383559
# dtype: float64
#
# Intercept:
# 0.7466804274392203
# MSE: 0.03622089137252841
# RMSE: 0.19031786929379071
# R2: 0.7343548999657232
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#BIS: Handgrip Strength
print("MLR: BIS Model, Handgrip Strength")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A'], 'tCOMB4IMaxGrip')
# Out:
# MLR: BIS Model, Handgrip Strength
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     29.24
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.13e-46
# Time:                        18:57:31   Log-Likelihood:                -343.52
# No. Observations:                 330   AIC:                             715.0
# Df Residuals:                     316   BIC:                             768.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.0677      2.621      1.933      0.054      -0.089      10.224
# COMB1PF7A       -0.2576      0.100     -2.581      0.010      -0.454      -0.061
# COMB4IMECF       6.4968      8.369      0.776      0.438      -9.969      22.962
# COMB4IMICF       6.4783      8.372      0.774      0.440      -9.994      22.951
# COMB4IMFFM      -4.7394      6.125     -0.774      0.440     -16.791       7.312
# COMB4DTBFM   -1.395e-05   7.04e-06     -1.982      0.048   -2.78e-05   -9.95e-08
# COMB4IRES0      -0.0015      0.004     -0.390      0.696      -0.009       0.006
# COMB4IRESINF     0.0065      0.013      0.479      0.632      -0.020       0.033
# COMB4IRESEXC    -0.0015      0.004     -0.390      0.696      -0.009       0.006
# COMB4IRESINC    -0.0014      0.001     -1.551      0.122      -0.003       0.000
# COMB4IFCHAR     -0.0204      0.016     -1.281      0.201      -0.052       0.011
# COMB4IMCAP      -0.3850      0.391     -0.984      0.326      -1.155       0.385
# COMB1PRSEX      -0.5672      0.278     -2.044      0.042      -1.113      -0.021
# COMB1PRAGE      -0.0037      0.004     -0.883      0.378      -0.012       0.005
# COMB4P1A         0.0269      0.014      1.864      0.063      -0.001       0.055
# ==============================================================================
# Omnibus:                        3.410   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                3.213
# Skew:                          -0.239   Prob(JB):                        0.201
# Kurtosis:                       3.076   Cond. No.                     2.55e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.81e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A      -0.257582
# COMB4IMECF      6.496819
# COMB4IMICF      6.478301
# COMB4IMFFM     -4.739409
# COMB4DTBFM     -0.000014
# COMB4IRES0     -0.001507
# COMB4IRESINF    0.006461
# COMB4IRESEXC   -0.001507
# COMB4IRESINC   -0.001391
# COMB4IFCHAR    -0.020390
# COMB4IMCAP     -0.385037
# COMB1PRSEX     -0.567232
# COMB1PRAGE     -0.003682
# COMB4P1A        0.026945
# dtype: float64
#
# Intercept:
# 5.067673947515211
# MSE: 0.43471811055028314
# RMSE: 0.6593315634415534
# R2: 0.5449075531657545
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#BIS: Jump Power

print("MLR: BIS Model, Jump Power")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A'], 'tjumppownums')
# Out:
# MLR: BIS Model, Jump Power
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     86.80
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           6.55e-96
# Time:                        18:57:42   Log-Likelihood:                 120.76
# No. Observations:                 330   AIC:                            -213.5
# Df Residuals:                     316   BIC:                            -160.3
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.8178      0.642      2.832      0.005       0.555       3.081
# COMB1PF7A        0.0140      0.024      0.574      0.566      -0.034       0.062
# COMB4IMECF      -1.2845      2.050     -0.627      0.531      -5.317       2.748
# COMB4IMICF      -1.0796      2.050     -0.527      0.599      -5.114       2.954
# COMB4IMFFM       0.8711      1.500      0.581      0.562      -2.080       3.822
# COMB4DTBFM   -3.046e-06   1.72e-06     -1.766      0.078   -6.44e-06    3.47e-07
# COMB4IRES0      -0.0029      0.001     -3.121      0.002      -0.005      -0.001
# COMB4IRESINF     0.0099      0.003      3.012      0.003       0.003       0.016
# COMB4IRESEXC    -0.0029      0.001     -3.121      0.002      -0.005      -0.001
# COMB4IRESINC    -0.0006      0.000     -2.915      0.004      -0.001      -0.000
# COMB4IFCHAR     -0.0130      0.004     -3.333      0.001      -0.021      -0.005
# COMB4IMCAP      -0.2493      0.096     -2.601      0.010      -0.438      -0.061
# COMB1PRSEX      -0.3827      0.068     -5.630      0.000      -0.516      -0.249
# COMB1PRAGE      -0.0095      0.001     -9.273      0.000      -0.011      -0.007
# COMB4P1A         0.0038      0.004      1.070      0.286      -0.003       0.011
# ==============================================================================
# Omnibus:                       55.630   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.546
# Skew:                          -0.807   Prob(JB):                     4.99e-31
# Kurtosis:                       5.746   Cond. No.                     2.55e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.81e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A       0.014042
# COMB4IMECF     -1.284505
# COMB4IMICF     -1.079626
# COMB4IMFFM      0.871070
# COMB4DTBFM     -0.000003
# COMB4IRES0     -0.002950
# COMB4IRESINF    0.009941
# COMB4IRESEXC   -0.002950
# COMB4IRESINC   -0.000640
# COMB4IFCHAR    -0.012997
# COMB4IMCAP     -0.249255
# COMB1PRSEX     -0.382652
# COMB1PRAGE     -0.009470
# COMB4P1A        0.003786
# dtype: float64
#
# Intercept:
# 1.8178386558411865
# MSE: 0.03398050905288938
# RMSE: 0.18433802931812354
# R2: 0.7507859308670478
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#COMBO: Handgrip Strength (ARMS)

print("MLR: Combo Models, Handgrip Strength (Arms)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4DALM', 'COMB4DABM', 'COMB4DAFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tCOMB4IMaxGrip')
# Out:
# MLR: Combo Models, Handgrip Strength (Arms)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     22.75
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           7.20e-45
# Time:                        18:57:58   Log-Likelihood:                -340.81
# No. Observations:                 330   AIC:                             717.6
# Df Residuals:                     312   BIC:                             786.0
# Df Model:                          17
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            4.8852      2.720      1.796      0.073      -0.466      10.236
# COMB1PF7A       -0.3333      0.109     -3.052      0.002      -0.548      -0.118
# COMB4DALM     7.722e-05   8.25e-05      0.936      0.350   -8.51e-05       0.000
# COMB4DABM        0.0011      0.001      0.998      0.319      -0.001       0.003
# COMB4DAFM     4.011e-05   7.27e-05      0.552      0.582      -0.000       0.000
# COMB1PRSEX      -0.4386      0.309     -1.419      0.157      -1.047       0.170
# COMB1PRAGE      -0.0044      0.004     -0.998      0.319      -0.013       0.004
# COMB4P1A         0.0267      0.015      1.794      0.074      -0.003       0.056
# COMB4DLR3MD     -0.3940      0.532     -0.741      0.459      -1.440       0.652
# COMB4IMECF       4.7945      8.434      0.568      0.570     -11.801      21.390
# COMB4IMICF       4.7490      8.438      0.563      0.574     -11.854      21.352
# COMB4IMFFM      -3.4973      6.172     -0.567      0.571     -15.641       8.647
# COMB4DTBFM   -1.382e-05   1.14e-05     -1.211      0.227   -3.63e-05    8.64e-06
# COMB4IRES0      -0.0011      0.004     -0.282      0.778      -0.009       0.007
# COMB4IRESINF     0.0053      0.014      0.385      0.700      -0.022       0.032
# COMB4IRESEXC    -0.0011      0.004     -0.282      0.778      -0.009       0.007
# COMB4IRESINC    -0.0014      0.001     -1.543      0.124      -0.003       0.000
# COMB4IFCHAR     -0.0151      0.016     -0.936      0.350      -0.047       0.017
# COMB4IMCAP      -0.3059      0.393     -0.778      0.437      -1.080       0.468
# ==============================================================================
# Omnibus:                        3.157   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.206   Jarque-Bera (JB):                2.974
# Skew:                          -0.230   Prob(JB):                        0.226
# Kurtosis:                       3.064   Cond. No.                     4.56e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.2e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A      -0.333320
# COMB4DALM       0.000077
# COMB4DABM       0.001142
# COMB4DAFM       0.000040
# COMB1PRSEX     -0.438592
# COMB1PRAGE     -0.004371
# COMB4P1A        0.026685
# COMB4DLR3MD    -0.394019
# COMB4IMECF      4.794550
# COMB4IMICF      4.749013
# COMB4IMFFM     -3.497312
# COMB4DTBFM     -0.000014
# COMB4IRES0     -0.001105
# COMB4IRESINF    0.005254
# COMB4IRESEXC   -0.001105
# COMB4IRESINC   -0.001392
# COMB4IFCHAR    -0.015092
# COMB4IMCAP     -0.305894
# dtype: float64
#
# Intercept:
# 4.885235935993535
# MSE: 0.41850778909165154
# RMSE: 0.6469217797320257
# R2: 0.561877618772729
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#COMBO: Handgrip Strength (TOTAL BODY)

print("MLR: Combo Models, Handgrip Strength (TB)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD', 'COMB4IMECF', 'COMB4IMICF','COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tCOMB4IMaxGrip')
# Out:
# MLR: Combo Models, Handgrip Strength (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         tCOMB4IMaxGrip   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     21.11
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           1.15e-43
# Time:                        18:58:15   Log-Likelihood:                -342.12
# No. Observations:                 330   AIC:                             722.2
# Df Residuals:                     311   BIC:                             794.4
# Df Model:                          18
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             4.1803      2.848      1.468      0.143      -1.423       9.783
# COMB1PF7A        -0.2896      0.114     -2.539      0.012      -0.514      -0.065
# COMB4IALM         0.0274      0.029      0.954      0.341      -0.029       0.084
# COMB4DTBBM       -0.0003      0.000     -0.963      0.336      -0.001       0.000
# COMB4DTBFM     -7.56e-06   3.65e-06     -2.069      0.039   -1.47e-05   -3.71e-07
# COMB1PRSEX       -0.5082      0.309     -1.646      0.101      -1.116       0.099
# COMB1PRAGE       -0.0031      0.005     -0.674      0.501      -0.012       0.006
# COMB4P1A          0.0298      0.015      1.974      0.049     9.1e-05       0.059
# COMB4DLR3MD       0.3842      0.536      0.717      0.474      -0.670       1.439
# COMB4DLFNMD      -0.1803      0.454     -0.397      0.691      -1.073       0.712
# COMB4DLSL14MD     0.2126      0.358      0.594      0.553      -0.492       0.917
# COMB4IMECF        8.4506      8.552      0.988      0.324      -8.376      25.278
# COMB4IMICF        8.4026      8.557      0.982      0.327      -8.435      25.240
# COMB4IMFFM       -6.1607      6.259     -0.984      0.326     -18.476       6.155
# COMB4DTBFM    -7.558e-06   3.65e-06     -2.069      0.039   -1.47e-05   -3.69e-07
# COMB4IRES0       -0.0005      0.004     -0.132      0.895      -0.008       0.007
# COMB4IRESINF      0.0037      0.014      0.272      0.786      -0.023       0.031
# COMB4IRESEXC     -0.0005      0.004     -0.132      0.895      -0.008       0.007
# COMB4IRESINC     -0.0013      0.001     -1.408      0.160      -0.003       0.001
# COMB4IFCHAR      -0.0187      0.017     -1.121      0.263      -0.051       0.014
# COMB4IMCAP       -0.3871      0.408     -0.948      0.344      -1.191       0.417
# ==============================================================================
# Omnibus:                        3.182   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.204   Jarque-Bera (JB):                3.135
# Skew:                          -0.238   Prob(JB):                        0.209
# Kurtosis:                       2.970   Cond. No.                     2.92e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.04e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A       -0.289582
# COMB4IALM        0.027358
# COMB4DTBBM      -0.000275
# COMB4DTBFM      -0.000008
# COMB1PRSEX      -0.508214
# COMB1PRAGE      -0.003060
# COMB4P1A         0.029773
# COMB4DLR3MD      0.384158
# COMB4DLFNMD     -0.180296
# COMB4DLSL14MD    0.212641
# COMB4IMECF       8.450621
# COMB4IMICF       8.402592
# COMB4IMFFM      -6.160703
# COMB4DTBFM      -0.000008
# COMB4IRES0      -0.000518
# COMB4IRESINF     0.003720
# COMB4IRESEXC    -0.000518
# COMB4IRESINC    -0.001288
# COMB4IFCHAR     -0.018671
# COMB4IMCAP      -0.387095
# dtype: float64
#
# Intercept:
# 4.180267318357515
# MSE: 0.44840021961448884
# RMSE: 0.669626925694068
# R2: 0.5305841920248981
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#COMBO: Jump Power (LEGS)

print("MLR: Combo Models, Jump Power (Legs)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4ILLM', 'COMB4DLBM', 'COMB4DLFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLFNMD', 'COMB4IMECF', 'COMB4IMICF', 'COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tjumppownums')
# Out:
# MLR: Combo Models, Jump Power (Legs)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     73.61
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           3.04e-98
# Time:                        18:58:32   Log-Likelihood:                 135.92
# No. Observations:                 330   AIC:                            -235.8
# Df Residuals:                     312   BIC:                            -167.5
# Df Model:                          17
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.1150      0.653      1.707      0.089      -0.170       2.400
# COMB1PF7A       -0.0240      0.026     -0.937      0.350      -0.075       0.026
# COMB4ILLM        0.0415      0.009      4.775      0.000       0.024       0.059
# COMB4DLBM     7.426e-05      0.000      0.588      0.557      -0.000       0.000
# COMB4DLFM    -1.091e-05    5.3e-06     -2.058      0.040   -2.13e-05   -4.77e-07
# COMB1PRSEX      -0.2516      0.072     -3.489      0.001      -0.393      -0.110
# COMB1PRAGE      -0.0085      0.001     -7.913      0.000      -0.011      -0.006
# COMB4P1A         0.0039      0.004      1.061      0.289      -0.003       0.011
# COMB4DLFNMD      0.0493      0.103      0.480      0.632      -0.153       0.251
# COMB4IMECF      -1.3871      2.000     -0.694      0.488      -5.322       2.547
# COMB4IMICF      -1.2387      2.000     -0.619      0.536      -5.174       2.697
# COMB4IMFFM       0.9537      1.463      0.652      0.515      -1.926       3.833
# COMB4DTBFM    6.625e-07   2.31e-06      0.287      0.774   -3.87e-06     5.2e-06
# COMB4IRES0      -0.0029      0.001     -3.129      0.002      -0.005      -0.001
# COMB4IRESINF     0.0103      0.003      3.231      0.001       0.004       0.017
# COMB4IRESEXC    -0.0029      0.001     -3.129      0.002      -0.005      -0.001
# COMB4IRESINC    -0.0008      0.000     -3.644      0.000      -0.001      -0.000
# COMB4IFCHAR     -0.0074      0.004     -1.909      0.057      -0.015       0.000
# COMB4IMCAP      -0.1251      0.096     -1.306      0.193      -0.314       0.063
# ==============================================================================
# Omnibus:                       81.468   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.216
# Skew:                          -1.033   Prob(JB):                     4.76e-65
# Kurtosis:                       7.156   Cond. No.                     2.87e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.86e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A      -2.404108e-02
# COMB4ILLM       4.152637e-02
# COMB4DLBM       7.425973e-05
# COMB4DLFM      -1.090663e-05
# COMB1PRSEX     -2.515908e-01
# COMB1PRAGE     -8.492247e-03
# COMB4P1A        3.876642e-03
# COMB4DLFNMD     4.925142e-02
# COMB4IMECF     -1.387130e+00
# COMB4IMICF     -1.238743e+00
# COMB4IMFFM      9.536928e-01
# COMB4DTBFM      6.625260e-07
# COMB4IRES0     -2.860610e-03
# COMB4IRESINF    1.030013e-02
# COMB4IRESEXC   -2.860610e-03
# COMB4IRESINC   -7.756723e-04
# COMB4IFCHAR    -7.422523e-03
# COMB4IMCAP     -1.250930e-01
# dtype: float64
#
# Intercept:
# 1.1150357106004338
# MSE: 0.0281403194963047
# RMSE: 0.16775076600810113
# R2: 0.7936180556489008
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21

# %%
#COMBO: Jump Power (TOTAL BODY)

print("MLR: Combo Models, Jump Power (TB)")

train_test_linear_regression(df, ['COMB1PF7A', 'COMB4IALM', 'COMB4DTBBM', 'COMB4DTBFM', 'COMB1PRSEX', 'COMB1PRAGE', 'COMB4P1A', 'COMB4DLR3MD', 'COMB4DLFNMD', 'COMB4DLSL14MD', 'COMB4IMECF', 'COMB4IMICF','COMB4IMFFM', 'COMB4DTBFM', 'COMB4IRES0', 'COMB4IRESINF', 'COMB4IRESEXC', 'COMB4IRESINC', 'COMB4IFCHAR', 'COMB4IMCAP'], 'tjumppownums')
# Out:
# MLR: Combo Models, Jump Power (TB)
#
# TRAINING Metrics
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           tjumppownums   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     77.18
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):          4.10e-103
# Time:                        18:58:46   Log-Likelihood:                 150.29
# No. Observations:                 330   AIC:                            -262.6
# Df Residuals:                     311   BIC:                            -190.4
# Df Model:                          18
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.0836      0.640      1.692      0.092      -0.176       2.344
# COMB1PF7A        -0.0607      0.026     -2.366      0.019      -0.111      -0.010
# COMB4IALM         0.0337      0.006      5.232      0.000       0.021       0.046
# COMB4DTBBM        0.0002   6.41e-05      2.605      0.010    4.09e-05       0.000
# COMB4DTBFM    -9.034e-07   8.22e-07     -1.099      0.272   -2.52e-06    7.13e-07
# COMB1PRSEX       -0.1677      0.069     -2.416      0.016      -0.304      -0.031
# COMB1PRAGE       -0.0076      0.001     -7.453      0.000      -0.010      -0.006
# COMB4P1A          0.0021      0.003      0.631      0.528      -0.005       0.009
# COMB4DLR3MD       0.1380      0.121      1.145      0.253      -0.099       0.375
# COMB4DLFNMD       0.0566      0.102      0.554      0.580      -0.144       0.257
# COMB4DLSL14MD    -0.2661      0.081     -3.306      0.001      -0.425      -0.108
# COMB4IMECF       -2.1029      1.923     -1.093      0.275      -5.887       1.681
# COMB4IMICF       -1.9764      1.924     -1.027      0.305      -5.763       1.810
# COMB4IMFFM        1.4824      1.408      1.053      0.293      -1.287       4.252
# COMB4DTBFM    -9.039e-07   8.22e-07     -1.100      0.272   -2.52e-06    7.13e-07
# COMB4IRES0       -0.0025      0.001     -2.772      0.006      -0.004      -0.001
# COMB4IRESINF      0.0089      0.003      2.894      0.004       0.003       0.015
# COMB4IRESEXC     -0.0025      0.001     -2.772      0.006      -0.004      -0.001
# COMB4IRESINC     -0.0007      0.000     -3.457      0.001      -0.001      -0.000
# COMB4IFCHAR      -0.0053      0.004     -1.425      0.155      -0.013       0.002
# COMB4IMCAP       -0.0872      0.092     -0.949      0.343      -0.268       0.094
# ==============================================================================
# Omnibus:                       61.634   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.109
# Skew:                          -0.825   Prob(JB):                     2.34e-41
# Kurtosis:                       6.300   Cond. No.                     2.92e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.04e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# TEST Metrics
#
# Coefficients:
# COMB1PF7A       -6.068805e-02
# COMB4IALM        3.372442e-02
# COMB4DTBBM       1.670434e-04
# COMB4DTBFM      -9.036054e-07
# COMB1PRSEX      -1.676986e-01
# COMB1PRAGE      -7.608120e-03
# COMB4P1A         2.141871e-03
# COMB4DLR3MD      1.379776e-01
# COMB4DLFNMD      5.655906e-02
# COMB4DLSL14MD   -2.661319e-01
# COMB4IMECF      -2.102927e+00
# COMB4IMICF      -1.976355e+00
# COMB4IMFFM       1.482445e+00
# COMB4DTBFM      -9.036882e-07
# COMB4IRES0      -2.451689e-03
# COMB4IRESINF     8.902933e-03
# COMB4IRESEXC    -2.451689e-03
# COMB4IRESINC    -7.112253e-04
# COMB4IFCHAR     -5.337187e-03
# COMB4IMCAP      -8.720284e-02
# dtype: float64
#
# Intercept:
# 1.0835620126469685
# MSE: 0.031706742248846766
# RMSE: 0.17806387126210294
# R2: 0.7674618045749111
#
# white train frequency:  251
# white test frequency:  62
#
# black train frequency:  79
# black test frequency:  21
